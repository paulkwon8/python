# %% [markdown]
# 유닛 15. pandas

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=0, index_col=0)

# %%
len(df) # 리스트 안에 요소 : 16개
# Out:
# 16

# %%
data = df[1]

# %%
type(data)  # 타입 : 데이터 프레임(컬럼,인덱스,밸류)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns  # 열의 데이터
# Out:
# Index(['Summer Games', 'Summer Games.1', 'Summer Games.2', 'Summer Games.3',
#        'Summer Games.4', 'Winter Games', 'Winter Games.1', 'Winter Games.2',
#        'Winter Games.3', 'Winter Games.4', 'Combined Total',
#        'Combined Total.1', 'Combined Total.2', 'Combined Total.3',
#        'Combined Total.4'],
#       dtype='object')

# %%
data.index # 가장 좌측의 데이터
# Out:
# Index(['Team (IOC code)', 'Afghanistan (AFG)', 'Algeria (ALG)',
#        'Argentina (ARG)', 'Armenia (ARM)', 'Australasia (ANZ) [ANZ]',
#        'Australia (AUS) [AUS] [Z]', 'Austria (AUT)', 'Azerbaijan (AZE)',
#        'Bahamas (BAH)',
#        ...
#        'Virgin Islands (ISV)', 'Yugoslavia (YUG) [YUG]', 'Zambia (ZAM) [ZAM]',
#        'Zimbabwe (ZIM) [ZIM]', 'Unified Team (EUN) [EUN]',
#        'Independent Olympic Athletes (IOA) [IOA]',
#        'Independent Olympic Participants (IOP) [IOP]',
#        'Olympic Athletes from Russia (OAR) [OAR]', 'Mixed team (ZZX) [ZZX]',
#        'Totals'],
#       dtype='object', length=154)

# %%
data.values # 실제 데이터(데이터 값들)
# Out:
# array([['№', nan, nan, ..., nan, nan, 'Total'],
#        ['14', 0.0, 0.0, ..., 0.0, 2.0, '2'],
#        ['13', 5.0, 4.0, ..., 4.0, 8.0, '17'],
#        ...,
#        ['0', 0.0, 0.0, ..., 6.0, 9.0, '17'],
#        ['3', 8.0, 5.0, ..., 5.0, 4.0, '17'],
#        ['28', 5115.0, 5081.0, ..., 6139.0, 6537.0, '18853']], dtype=object)

# %%
data.head()
# Out:
#                   Summer Games  Summer Games.1  Summer Games.2  \
# Team (IOC code)              №             NaN             NaN
# Afghanistan (AFG)           14             0.0             0.0
# Algeria (ALG)               13             5.0             4.0
# Argentina (ARG)             24            21.0            25.0
# Armenia (ARM)                6             2.0             6.0
#
#                    Summer Games.3 Summer Games.4 Winter Games  Winter Games.1  \
# Team (IOC code)               NaN          Total            №             NaN
# Afghanistan (AFG)             2.0              2            0             0.0
# Algeria (ALG)                 8.0             17            3             0.0
# Argentina (ARG)              28.0             74           19             0.0
# Armenia (ARM)                 6.0             14            7             0.0
#
#                    Winter Games.2  Winter Games.3 Winter Games.4  \
# ...

# %%
data.shape
# Out:
# (154, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, Team (IOC code) to Totals
# Data columns (total 15 columns):
# Summer Games        154 non-null object
# Summer Games.1      153 non-null float64
# Summer Games.2      153 non-null float64
# Summer Games.3      153 non-null float64
# Summer Games.4      154 non-null object
# Winter Games        154 non-null object
# Winter Games.1      153 non-null float64
# Winter Games.2      153 non-null float64
# Winter Games.3      153 non-null float64
# Winter Games.4      154 non-null object
# Combined Total      154 non-null object
# Combined Total.1    153 non-null float64
# Combined Total.2    153 non-null float64
# Combined Total.3    153 non-null float64
# Combined Total.4    154 non-null object
# dtypes: float64(9), object(6)
# memory usage: 19.2+ KB

# %%
data.describe() #기술하다. 통계치 구하기(수치 데이터 컬럼만)
# Out:
#        Summer Games.1  Summer Games.2  Summer Games.3  Winter Games.1  \
# count      153.000000      153.000000      153.000000      153.000000
# mean        66.862745       66.418301       71.725490       13.882353
# std        422.599849      416.404023      447.853436       87.722270
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        1.000000        1.000000        0.000000
# 50%          3.000000        4.000000        6.000000        0.000000
# 75%         26.000000       30.000000       31.000000        1.000000
# max       5115.000000     5081.000000     5487.000000     1062.000000
#
#        Winter Games.2  Winter Games.3  Combined Total.1  Combined Total.2  \
# count      153.000000      153.000000        153.000000        153.000000
# mean        13.830065       13.725490         80.745098         80.248366
# std         87.279179       86.350893        508.851901        502.521776
# ...

# %%
data.head(3) # 상단에 3개 보겠다
# Out:
#                   Summer Games  Summer Games.1  Summer Games.2  \
# Team (IOC code)              №             NaN             NaN
# Afghanistan (AFG)           14             0.0             0.0
# Algeria (ALG)               13             5.0             4.0
#
#                    Summer Games.3 Summer Games.4 Winter Games  Winter Games.1  \
# Team (IOC code)               NaN          Total            №             NaN
# Afghanistan (AFG)             2.0              2            0             0.0
# Algeria (ALG)                 8.0             17            3             0.0
#
#                    Winter Games.2  Winter Games.3 Winter Games.4  \
# Team (IOC code)               NaN             NaN          Total
# Afghanistan (AFG)             0.0             0.0              0
# Algeria (ALG)                 0.0             0.0              0
#
#                   Combined Total  Combined Total.1  Combined Total.2  \
# ...

# %%
data.tail(3) # 하단에 3개 보겠다
# Out:
#                                          Summer Games  Summer Games.1  \
# Olympic Athletes from Russia (OAR) [OAR]            0             0.0
# Mixed team (ZZX) [ZZX]                              3             8.0
# Totals                                             28          5115.0
#
#                                           Summer Games.2  Summer Games.3  \
# Olympic Athletes from Russia (OAR) [OAR]             0.0             0.0
# Mixed team (ZZX) [ZZX]                               5.0             4.0
# Totals                                            5081.0          5487.0
#
#                                          Summer Games.4 Winter Games  \
# Olympic Athletes from Russia (OAR) [OAR]              0            1
# Mixed team (ZZX) [ZZX]                               17            0
# Totals                                            15683           23
#
#                                           Winter Games.1  Winter Games.2  \
# ...

# %%
data.sample(5) # 아무거나 5개 보겠다
# Out:
#                          Summer Games  Summer Games.1  Summer Games.2  \
# Tajikistan (TJK)                    6             1.0             1.0
# Soviet Union (URS) [URS]            9           395.0           319.0
# Cyprus (CYP)                       10             0.0             1.0
# Zimbabwe (ZIM) [ZIM]               13             3.0             4.0
# Kosovo (KOS)                        1             1.0             0.0
#
#                           Summer Games.3 Summer Games.4 Winter Games  \
# Tajikistan (TJK)                     2.0              4            4
# Soviet Union (URS) [URS]           296.0           1010            9
# Cyprus (CYP)                         0.0              1           11
# Zimbabwe (ZIM) [ZIM]                 1.0              8            1
# Kosovo (KOS)                         0.0              1            1
#
#                           Winter Games.1  Winter Games.2  Winter Games.3  \
# ...

# %%
d = {'a':'1','b':[1,2,3], 'c':100}
d['b']
# Out:
# [1, 2, 3]

# %%
# 데이터 프레임은 딕셔너리 구조로 되어있습니다.
#data[['Summer Games.1','Summer Games.2']].head()  #몇개의 컬럼만 뽑기

# %%
#data[0] 에 해당 i(index)loc(location)
data.iloc[0:5]
# Out:
#                   Summer Games  Summer Games.1  Summer Games.2  \
# Team (IOC code)              №             NaN             NaN
# Afghanistan (AFG)           14             0.0             0.0
# Algeria (ALG)               13             5.0             4.0
# Argentina (ARG)             24            21.0            25.0
# Armenia (ARM)                6             2.0             6.0
#
#                    Summer Games.3 Summer Games.4 Winter Games  Winter Games.1  \
# Team (IOC code)               NaN          Total            №             NaN
# Afghanistan (AFG)             2.0              2            0             0.0
# Algeria (ALG)                 8.0             17            3             0.0
# Argentina (ARG)              28.0             74           19             0.0
# Armenia (ARM)                 6.0             14            7             0.0
#
#                    Winter Games.2  Winter Games.3 Winter Games.4  \
# ...

# %%
data.iloc[:5,:3]
# Out:
#                   Summer Games  Summer Games.1  Summer Games.2
# Team (IOC code)              №             NaN             NaN
# Afghanistan (AFG)           14             0.0             0.0
# Algeria (ALG)               13             5.0             4.0
# Argentina (ARG)             24            21.0            25.0
# Armenia (ARM)                6             2.0             6.0

# %%
data.dtypes  # type검사 1
# Out:
# Summer Games         object
# Summer Games.1      float64
# Summer Games.2      float64
# Summer Games.3      float64
# Summer Games.4       object
# Winter Games         object
# Winter Games.1      float64
# Winter Games.2      float64
# Winter Games.3      float64
# Winter Games.4       object
# Combined Total       object
# Combined Total.1    float64
# Combined Total.2    float64
# Combined Total.3    float64
# Combined Total.4     object
# dtype: object

# %%
data.info()  # type검사 2
# 수치형이어야하는데 Object로 잡혔다면 누락이나 오타가 있는 것
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 154 entries, Team (IOC code) to Totals
# Data columns (total 15 columns):
# Summer Games        154 non-null object
# Summer Games.1      153 non-null float64
# Summer Games.2      153 non-null float64
# Summer Games.3      153 non-null float64
# Summer Games.4      154 non-null object
# Winter Games        154 non-null object
# Winter Games.1      153 non-null float64
# Winter Games.2      153 non-null float64
# Winter Games.3      153 non-null float64
# Winter Games.4      154 non-null object
# Combined Total      154 non-null object
# Combined Total.1    153 non-null float64
# Combined Total.2    153 non-null float64
# Combined Total.3    153 non-null float64
# Combined Total.4    154 non-null object
# dtypes: float64(9), object(6)
# memory usage: 19.2+ KB

# %%
data.max()  # 컬럼별 최대값
# Out:
# Summer Games            №
# Summer Games.1       5115
# Summer Games.2       5081
# Summer Games.3       5487
# Summer Games.4      Total
# Winter Games            №
# Winter Games.1       1062
# Winter Games.2       1058
# Winter Games.3       1050
# Winter Games.4      Total
# Combined Total          №
# Combined Total.1     6177
# Combined Total.2     6139
# Combined Total.3     6537
# Combined Total.4    Total
# dtype: object

# %%
 data.min()  # 컬럼별 최소값
# Out:
# Summer Games        0.0
# Summer Games.1      0.0
# Summer Games.2      0.0
# Summer Games.3      0.0
# Summer Games.4      0.0
# Winter Games        0.0
# Winter Games.1      0.0
# Winter Games.2      0.0
# Winter Games.3      0.0
# Winter Games.4      0.0
# Combined Total      1.0
# Combined Total.1    0.0
# Combined Total.2    0.0
# Combined Total.3    0.0
# Combined Total.4    1.0
# dtype: float64

# %%
data.std() #컬럼별 최대값
# Out:
# Summer Games.1      422.599849
# Summer Games.2      416.404023
# Summer Games.3      447.853436
# Winter Games.1       87.722270
# Winter Games.2       87.279179
# Winter Games.3       86.350893
# Combined Total.1    508.851901
# Combined Total.2    502.521776
# Combined Total.3    533.219133
# dtype: float64

# %%
new_data = data.dropna()  #누락 값이 있는 행을 제거해서 리턴
new_data.head()
# Out:
#                         Summer Games  Summer Games.1  Summer Games.2  \
# Afghanistan (AFG)                 14             0.0             0.0
# Algeria (ALG)                     13             5.0             4.0
# Argentina (ARG)                   24            21.0            25.0
# Armenia (ARM)                      6             2.0             6.0
# Australasia (ANZ) [ANZ]            2             3.0             4.0
#
#                          Summer Games.3 Summer Games.4 Winter Games  \
# Afghanistan (AFG)                   2.0              2            0
# Algeria (ALG)                       8.0             17            3
# Argentina (ARG)                    28.0             74           19
# Armenia (ARM)                       6.0             14            7
# Australasia (ANZ) [ANZ]             5.0             12            0
#
#                          Winter Games.1  Winter Games.2  Winter Games.3  \
# ...

# %%
new_data.max()
# Out:
# Summer Games           9.0
# Summer Games.1      5115.0
# Summer Games.2      5081.0
# Summer Games.3      5487.0
# Summer Games.4        91.0
# Winter Games           9.0
# Winter Games.1      1062.0
# Winter Games.2      1058.0
# Winter Games.3      1050.0
# Winter Games.4         9.0
# Combined Total         9.0
# Combined Total.1    6177.0
# Combined Total.2    6139.0
# Combined Total.3    6537.0
# Combined Total.4      96.0
# dtype: float64

# %%
# data[10:20, :2] 행은 선택이 되는데 컬럼 선택이 안됩니다.
data.iloc[10:20, :2]
# Out:
#                                 Summer Games  Summer Games.1
# Bahrain (BRN)                              9             2.0
# Barbados (BAR) [BAR]                      12             0.0
# Belarus (BLR)                              6            12.0
# Belgium (BEL)                             26            40.0
# Bermuda (BER)                             18             0.0
# Bohemia (BOH) [BOH] [Z]                    3             0.0
# Botswana (BOT)                            10             0.0
# Brazil (BRA)                              22            30.0
# British West Indies (BWI) [BWI]            1             0.0
# Bulgaria (BUL) [H]                        20            51.0

# %%
data.head()
#정렬
data.sort_values('Summer Games', ascending=False).head()
# Out:
#                 Summer Games  Summer Games.1  Summer Games.2  Summer Games.3  \
# Team (IOC code)            №             NaN             NaN             NaN
# Lithuania (LTU)            9             6.0             6.0            13.0
# Samoa (SAM)                9             0.0             1.0             0.0
# Qatar (QAT)                9             0.0             1.0             4.0
# Mauritius (MRI)            9             0.0             0.0             1.0
#
#                 Summer Games.4 Winter Games  Winter Games.1  Winter Games.2  \
# Team (IOC code)          Total            №             NaN             NaN
# Lithuania (LTU)             25            9             0.0             0.0
# Samoa (SAM)                  1            0             0.0             0.0
# Qatar (QAT)                  5            0             0.0             0.0
# Mauritius (MRI)              1            0             0.0             0.0
#
# ...

# %%
# 256 데이터를 엑셀로 저장하기
data.head()
summer = data.iloc[1:,:5]
summer.head(5)
# Out:
#                         Summer Games  Summer Games.1  Summer Games.2  \
# Afghanistan (AFG)                 14             0.0             0.0
# Algeria (ALG)                     13             5.0             4.0
# Argentina (ARG)                   24            21.0            25.0
# Armenia (ARM)                      6             2.0             6.0
# Australasia (ANZ) [ANZ]            2             3.0             4.0
#
#                          Summer Games.3 Summer Games.4
# Afghanistan (AFG)                   2.0              2
# Algeria (ALG)                       8.0             17
# Argentina (ARG)                    28.0             74
# Armenia (ARM)                       6.0             14
# Australasia (ANZ) [ANZ]             5.0             12

# %%
summer.columns
# Out:
# Index(['Summer Games', 'Summer Games.1', 'Summer Games.2', 'Summer Games.3',
#        'Summer Games.4'],
#       dtype='object')

# %%
summer.columns = ['경기수','금','은','동','계']

# %%
summer.head()
# Out:
#                         경기수     금     은     동   계
# Afghanistan (AFG)        14   0.0   0.0   2.0   2
# Algeria (ALG)            13   5.0   4.0   8.0  17
# Argentina (ARG)          24  21.0  25.0  28.0  74
# Armenia (ARM)             6   2.0   6.0   6.0  14
# Australasia (ANZ) [ANZ]   2   3.0   4.0   5.0  12

# %%
summer.sort_values('금', ascending=False).to_excel('하계올림픽메달.xlsx')

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_table_of_the_FIFA_World_Cup', index_col=0, header=2)

# %%
len(df)
# Out:
# 4

# %%
for i in range(len(df)):
    data = df[i]
    print(data.shape)
# Out:
# (79, 18)
# (12, 18)
# (11, 1)
# (6, 1)

# %%
worldcup = df[0]

# %%
#컬럼 'T' 내림차순으로 정렬해서 엑셀로 저장합니다.
worldcup.shape
worldcup_sort = worldcup.sort_values('T', ascending=False)

# %%
worldcup_sort.to_excel('worldcup.xlsx')

# %%
worldcup.head(3)
# Out:
#          Team   T    S    P   W   D   L    F    A    GD  T.1    A.1  T.2  \
# №
# 1      Brazil  21  +21  109  73  18  18  229  105  +124  237  2.174  164
# 2  Germany[A]  19  +17  109  67  20  22  226  125  +101  221  2.028  154
# 3       Italy  18   −1   83  45  21  17  128   77   +51  156  1.880  111
#
#      A.2  T.3    A.3                              Best finish Confederation
# №
# 1  1.505  193  1.771  Champion (1958, 1962, 1970, 1994, 2002)      CONMEBOL
# 2  1.413  182  1.670        Champion (1954, 1974, 1990, 2014)          UEFA
# 3  1.337  125  1.506        Champion (1934, 1938, 1982, 2006)          UEFA

# %%
url = 'www.google.com'
url = 'https://finance.yahoo.com/quote/%5EGSPC/history?p=%5EGSPC'
url = 'https://finance.naver.com'
df = pd.read_html(url, encoding = 'cp949', header=1, index_col=0)

# %%
len(df)
# Out:
# 12

# %%
df[0]
# Out:
#          Unnamed: 1 Unnamed: 2  Unnamed: 3 Unnamed: 4  Unnamed: 5 Unnamed: 6
# 아이앤씨            NaN    +17.80%         NaN    +14.02%         NaN   19.06.14
# 이녹스첨단소재         NaN    +16.34%         NaN    +31.22%         NaN   19.05.23
# 파수닷컴            NaN    +12.41%         NaN    +21.10%         NaN   19.05.21
# 인선이엔티           NaN    +11.08%         NaN    -13.37%         NaN   19.05.02
# 디바이스이엔지         NaN    +10.48%         NaN      0.00%         NaN   19.03.20

# %%
wise = df[0]

# %%
wise_save = wise.iloc[:,1::2] # 1번째 컬럼부터 2칸씩 떨어져서

# %%
wise_save.to_excel('naver_wise.xlsx')

# %%
wise_save
# Out:
#         Unnamed: 2 Unnamed: 4 Unnamed: 6
# 아이앤씨       +17.80%    +14.02%   19.06.14
# 이녹스첨단소재    +16.34%    +31.22%   19.05.23
# 파수닷컴       +12.41%    +21.10%   19.05.21
# 인선이엔티      +11.08%    -13.37%   19.05.02
# 디바이스이엔지    +10.48%      0.00%   19.03.20

# %%
wise_save = wise_save.replace('%', '', regex=True)
wise_save.columns = ['1주','누적','추천일']
wise_save
# Out:
#              1주      누적       추천일
# 아이앤씨     +17.80  +14.02  19.06.14
# 이녹스첨단소재  +16.34  +31.22  19.05.23
# 파수닷컴     +12.41  +21.10  19.05.21
# 인선이엔티    +11.08  -13.37  19.05.02
# 디바이스이엔지  +10.48    0.00  19.03.20

# %%
#259 pandas란 panel datas 데이터 분석용 라이브러리
#values를 numpy로 관리
# 컬럼 > 시리즈, 표  > 데이터 프레임

# %%
import numpy as np

# %%
#260
index = pd.date_range('1/1/2000',periods=8)

# %%
index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
#dataframe의 구성요소 (values, index, columns)
df = pd.DataFrame(data=np.random.rand(8,3), index=index, columns=list('abc'))
#df = pd.DataFrame(data=np.random.rand(8,3), index=index, columns=list('A','B','C'))

# %%
df
# Out:
#                    a         b         c
# 2000-01-01  0.607500  0.377901  0.870088
# 2000-01-02  0.152905  0.414409  0.419182
# 2000-01-03  0.367133  0.176657  0.456443
# 2000-01-04  0.663785  0.869843  0.354079
# 2000-01-05  0.164998  0.553360  0.412598
# 2000-01-06  0.025705  0.260123  0.189791
# 2000-01-07  0.315948  0.594340  0.005401
# 2000-01-08  0.540927  0.465590  0.575526

# %%
df.T  # 가로로 보기 편할때
# Out:
#    2000-01-01  2000-01-02  2000-01-03  2000-01-04  2000-01-05  2000-01-06  \
# a    0.607500    0.152905    0.367133    0.663785    0.164998    0.025705
# b    0.377901    0.414409    0.176657    0.869843    0.553360    0.260123
# c    0.870088    0.419182    0.456443    0.354079    0.412598    0.189791
#
#    2000-01-07  2000-01-08
# a    0.315948    0.540927
# b    0.594340    0.465590
# c    0.005401    0.575526

# %%
# Boolean Mask a컬럼에서 0.5 보다 큰 값만 뽑기 x[x>0.5]
#df[df ['a']> 0.5]['a']
a=df['a']
a[ a > 0.5]
# Out:
# 2000-01-01    0.607500
# 2000-01-04    0.663785
# 2000-01-08    0.540927
# Name: a, dtype: float64

# %%
df.iloc[:4,:2]
# Out:
#                    a         b
# 2000-01-01  0.607500  0.377901
# 2000-01-02  0.152905  0.414409
# 2000-01-03  0.367133  0.176657
# 2000-01-04  0.663785  0.869843

# %%
a = df['a']
b = df['b']

# %%
a_b_mean = (a + b) / 2
a_b_mean
# Out:
# 2000-01-01    0.492700
# 2000-01-02    0.283657
# 2000-01-03    0.271895
# 2000-01-04    0.766814
# 2000-01-05    0.359179
# 2000-01-06    0.142914
# 2000-01-07    0.455144
# 2000-01-08    0.503258
# Freq: D, dtype: float64

# %%
d = {'a':4, 'b':5}  #c:10 추가

# %%
d['c'] =10

# %%
d
# Out:
# {'a': 4, 'b': 5, 'c': 10}

# %%
df['ab_mean'] = a_b_mean # 새로운 컬럼 추가하기
df
# Out:
#                    a         b         c   ab_mean
# 2000-01-01  0.607500  0.377901  0.870088  0.492700
# 2000-01-02  0.152905  0.414409  0.419182  0.283657
# 2000-01-03  0.367133  0.176657  0.456443  0.271895
# 2000-01-04  0.663785  0.869843  0.354079  0.766814
# 2000-01-05  0.164998  0.553360  0.412598  0.359179
# 2000-01-06  0.025705  0.260123  0.189791  0.142914
# 2000-01-07  0.315948  0.594340  0.005401  0.455144
# 2000-01-08  0.540927  0.465590  0.575526  0.503258

# %%
#265
df['D'] = df['a'] / df['b']
df['E'] = np.sum(df,axis=1)
df.head()
df.to_csv('test.csv')

# %%
del df['a'] 
df
# Out:
#                    b         c   ab_mean         D         E
# 2000-01-01  0.377901  0.870088  0.492700  1.607564  3.955753
# 2000-01-02  0.414409  0.419182  0.283657  0.368972  1.639125
# 2000-01-03  0.176657  0.456443  0.271895  2.078227  3.350355
# 2000-01-04  0.869843  0.354079  0.766814  0.763109  3.417630
# 2000-01-05  0.553360  0.412598  0.359179  0.298176  1.788311
# 2000-01-06  0.260123  0.189791  0.142914  0.098819  0.717351
# 2000-01-07  0.594340  0.005401  0.455144  0.531595  1.902428
# 2000-01-08  0.465590  0.575526  0.503258  1.161810  3.247110

# %%
df.head(2)
# Out:
#                    b         c   ab_mean         D         E
# 2000-01-01  0.377901  0.870088  0.492700  1.607564  3.955753
# 2000-01-02  0.414409  0.419182  0.283657  0.368972  1.639125

# %%
np.sum(df, axis=0)
# Out:
# b           3.712221
# c           3.283108
# ab_mean     3.275561
# D           6.908272
# E          20.018063
# dtype: float64

# %%
#268 pandas로 인구구조 분석하기

# %%
df = pd.read_csv('age.csv', encoding='cp949', index_col=0)
df.head()
# Out:
#                             2019년02월_계_총인구수 2019년02월_계_연령구간인구수 2019년02월_계_0세  \
# 행정구역
# 서울특별시  (1100000000)               9,770,638          9,770,638        53,738
# 서울특별시 종로구 (1111000000)              152,880            152,880           593
# 서울특별시 종로구 청운효자동(1111051500)          13,010             13,010            66
# 서울특별시 종로구 사직동(1111053000)             9,584              9,584            43
# 서울특별시 종로구 삼청동(1111054000)             2,820              2,820             9
#
#                             2019년02월_계_1세 2019년02월_계_2세 2019년02월_계_3세  \
# 행정구역
# 서울특별시  (1100000000)                59,599        65,815        70,726
# 서울특별시 종로구 (1111000000)                683           775           874
# 서울특별시 종로구 청운효자동(1111051500)            79            72            98
# 서울특별시 종로구 사직동(1111053000)              50            64            67
# 서울특별시 종로구 삼청동(1111054000)              15             3            21
#
# ...

# %%
df.shape
# Out:
# (3841, 103)

# %%
df.info
# Out:
# <bound method DataFrame.info of                                   2019년02월_계_총인구수 2019년02월_계_연령구간인구수  \
# 행정구역
# 서울특별시  (1100000000)                     9,770,638          9,770,638
# 서울특별시 종로구 (1111000000)                    152,880            152,880
# 서울특별시 종로구 청운효자동(1111051500)                13,010             13,010
# 서울특별시 종로구 사직동(1111053000)                   9,584              9,584
# 서울특별시 종로구 삼청동(1111054000)                   2,820              2,820
# 서울특별시 종로구 부암동(1111055000)                  10,142             10,142
# 서울특별시 종로구 평창동(1111056000)                  18,881             18,881
# 서울특별시 종로구 무악동(1111057000)                   8,415              8,415
# 서울특별시 종로구 교남동(1111058000)                  10,704             10,704
# 서울특별시 종로구 가회동(1111060000)                   4,412              4,412
# 서울특별시 종로구 종로1.2.3.4가동(1111061500)           7,347              7,347
# 서울특별시 종로구 종로5.6가동(1111063000)               5,220              5,220
# ...

# %%
df = df.dropna()  # 누락 행 제거

# %%
df = df.replace(',','', regex=True) # 콤마 제거

# %%
a = df.astype('int')

# %%
a
# Out:
#                                    2019년02월_계_총인구수  2019년02월_계_연령구간인구수  \
# 행정구역
# 서울특별시  (1100000000)                        9770638             9770638
# 서울특별시 종로구 (1111000000)                      152880              152880
# 서울특별시 종로구 청운효자동(1111051500)                  13010               13010
# 서울특별시 종로구 사직동(1111053000)                     9584                9584
# 서울특별시 종로구 삼청동(1111054000)                     2820                2820
# 서울특별시 종로구 부암동(1111055000)                    10142               10142
# 서울특별시 종로구 평창동(1111056000)                    18881               18881
# 서울특별시 종로구 무악동(1111057000)                     8415                8415
# 서울특별시 종로구 교남동(1111058000)                    10704               10704
# 서울특별시 종로구 가회동(1111060000)                     4412                4412
# 서울특별시 종로구 종로1.2.3.4가동(1111061500)             7347                7347
# 서울특별시 종로구 종로5.6가동(1111063000)                 5220                5220
# ...

# %%
a.dtypes  # a.info()
# Out:
# 2019년02월_계_총인구수       int32
# 2019년02월_계_연령구간인구수    int32
# 2019년02월_계_0세         int32
# 2019년02월_계_1세         int32
# 2019년02월_계_2세         int32
# 2019년02월_계_3세         int32
# 2019년02월_계_4세         int32
# 2019년02월_계_5세         int32
# 2019년02월_계_6세         int32
# 2019년02월_계_7세         int32
# 2019년02월_계_8세         int32
# 2019년02월_계_9세         int32
# 2019년02월_계_10세        int32
# 2019년02월_계_11세        int32
# 2019년02월_계_12세        int32
# 2019년02월_계_13세        int32
# 2019년02월_계_14세        int32
# 2019년02월_계_15세        int32
# 2019년02월_계_16세        int32
# 2019년02월_계_17세        int32
# 2019년02월_계_18세        int32
# 2019년02월_계_19세        int32
# 2019년02월_계_20세        int32
# 2019년02월_계_21세        int32
# 2019년02월_계_22세        int32
# 2019년02월_계_23세        int32
# 2019년02월_계_24세        int32
# 2019년02월_계_25세        int32
# 2019년02월_계_26세        int32
# 2019년02월_계_27세        int32
#                       ...
# 2019년02월_계_71세        int32
# 2019년02월_계_72세        int32
# ...

# %%
#인구를 총인구수로 나눈다  인구수 > 비율
b = a.div(a.iloc[:, 0], axis=0)   #비율 데이터
c = b.iloc[:,2:] # 컬럼 2개 빼고 선택
c.head(3)
# Out:
#                              2019년02월_계_0세  2019년02월_계_1세  2019년02월_계_2세  \
# 행정구역
# 서울특별시  (1100000000)               0.005500       0.006100       0.006736
# 서울특별시 종로구 (1111000000)            0.003879       0.004468       0.005069
# 서울특별시 종로구 청운효자동(1111051500)       0.005073       0.006072       0.005534
#
#                              2019년02월_계_3세  2019년02월_계_4세  2019년02월_계_5세  \
# 행정구역
# 서울특별시  (1100000000)               0.007239       0.007168       0.007062
# 서울특별시 종로구 (1111000000)            0.005717       0.005573       0.005645
# 서울특별시 종로구 청운효자동(1111051500)       0.007533       0.007533       0.007225
#
#                              2019년02월_계_6세  2019년02월_계_7세  2019년02월_계_8세  \
# 행정구역
# 서울특별시  (1100000000)               0.007817       0.007548       0.007741
# 서울특별시 종로구 (1111000000)            0.006692       0.005913       0.006620
# 서울특별시 종로구 청운효자동(1111051500)       0.008301       0.008378       0.008839
#
# ...

# %%
# 2. 궁금한 지역의 이름을 입력받는다.
name = input('궁금한 지역이 어디에요?')
name
# Out:
# 궁금한 지역이 어디에요?부림동
# '부림동'

# %%
#c.index.str.contains(name).sum()
mask = c.index.str.contains(name)
df2 = c[mask]
df2.head(2)
# Out:
#                              2019년02월_계_0세  2019년02월_계_1세  2019년02월_계_2세  \
# 행정구역
# 경기도 안양시 동안구 부림동(4117356600)       0.012396       0.010453       0.011308
# 경기도 과천시 부림동(4129054000)           0.004596       0.006469       0.007660
#
#                              2019년02월_계_3세  2019년02월_계_4세  2019년02월_계_5세  \
# 행정구역
# 경기도 안양시 동안구 부림동(4117356600)       0.011463       0.009754       0.008782
# 경기도 과천시 부림동(4129054000)           0.007916       0.008171       0.007745
#
#                              2019년02월_계_6세  2019년02월_계_7세  2019년02월_계_8세  \
# 행정구역
# 경기도 안양시 동안구 부림동(4117356600)       0.008432        0.00987       0.007966
# 경기도 과천시 부림동(4129054000)           0.009873        0.00715       0.006809
#
#                              2019년02월_계_9세  ...  2019년02월_계_91세  \
# 행정구역                                        ...
# 경기도 안양시 동안구 부림동(4117356600)       0.007189  ...        0.000427
# 경기도 과천시 부림동(4129054000)           0.008426  ...        0.001021
#
# ...

# %%
c.index.str.contains(name).sum()
# Out:
# 2

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='Malgun Gothic')
df2.T.plot()

# %%
c
# Out:
#                                    2019년02월_계_0세  2019년02월_계_1세  \
# 행정구역
# 서울특별시  (1100000000)                     0.005500       0.006100
# 서울특별시 종로구 (1111000000)                  0.003879       0.004468
# 서울특별시 종로구 청운효자동(1111051500)             0.005073       0.006072
# 서울특별시 종로구 사직동(1111053000)               0.004487       0.005217
# 서울특별시 종로구 삼청동(1111054000)               0.003191       0.005319
# 서울특별시 종로구 부암동(1111055000)               0.003352       0.005029
# 서울특별시 종로구 평창동(1111056000)               0.004290       0.005720
# 서울특별시 종로구 무악동(1111057000)               0.002377       0.005466
# 서울특별시 종로구 교남동(1111058000)               0.009062       0.007380
# 서울특별시 종로구 가회동(1111060000)               0.003173       0.003853
# 서울특별시 종로구 종로1.2.3.4가동(1111061500)       0.002450       0.002178
# 서울특별시 종로구 종로5.6가동(1111063000)           0.001916       0.002299
# 서울특별시 종로구 이화동(1111064000)               0.002963       0.002716
# 서울특별시 종로구 혜화동(1111065000)               0.002351       0.002997
# ...

# %%
df = c
x =df.sub(df2.iloc[0], axis=1)  # 원본과 내가 관심있는 지역의 0번째 행을 뺀다.
y = np.power(x,2) #제곱 -- 음수값을 없애기 위해, np.abs(x) 절대값으로 해도 됨
z = y.sum(axis=1) #나이별 차이를 다 누적시킨다.
z
# Out:
# 행정구역
# 서울특별시  (1100000000)                  0.000939
# 서울특별시 종로구 (1111000000)               0.001636
# 서울특별시 종로구 청운효자동(1111051500)          0.001095
# 서울특별시 종로구 사직동(1111053000)            0.001285
# 서울특별시 종로구 삼청동(1111054000)            0.002475
# 서울특별시 종로구 부암동(1111055000)            0.001723
# 서울특별시 종로구 평창동(1111056000)            0.001791
# 서울특별시 종로구 무악동(1111057000)            0.001860
# 서울특별시 종로구 교남동(1111058000)            0.000511
# 서울특별시 종로구 가회동(1111060000)            0.001873
# 서울특별시 종로구 종로1.2.3.4가동(1111061500)    0.004564
# 서울특별시 종로구 종로5.6가동(1111063000)        0.003695
# 서울특별시 종로구 이화동(1111064000)            0.002742
# 서울특별시 종로구 혜화동(1111065000)            0.003532
# 서울특별시 종로구 창신제1동(1111067000)          0.004366
# 서울특별시 종로구 창신제2동(1111068000)          0.003327
# 서울특별시 종로구 창신제3동(1111069000)          0.001613
# 서울특별시 종로구 숭인제1동(1111070000)          0.001871
# 서울특별시 종로구 숭인제2동(1111071000)          0.002741
# 서울특별시 중구 (1114000000)                0.001435
# ...

# %%
z.sort_values()
# Out:
# 행정구역
# 경기도 안양시 동안구 부림동(4117356600)         0.000000
# 경기도 군포시 오금동(4141058000)             0.000257
# 경기도 광명시 하안2동(4121063200)            0.000271
# 인천광역시 서구 검암경서동(2826051500)          0.000282
# 충청남도 천안시 서북구 (4413300000)           0.000323
# 서울특별시 서초구 서초2동(1165052000)          0.000346
# 충청남도 당진시 당진1동(4427051000)           0.000370
# 경기도 광명시 철산4동(4121062000)            0.000372
# 경기도 평택시 포승읍(4122025600)             0.000375
# 경기도 용인시 기흥구 구갈동(4146352000)         0.000379
# 경기도 부천시 상1동(4119063000)             0.000390
# 경기도 성남시 분당구 정자동(4113554500)         0.000390
# 경기도 용인시 수지구 죽전2동(4146555000)        0.000391
# 서울특별시 구로구 구로제1동(1153052000)         0.000419
# 경기도 광명시 소하2동(4121065000)            0.000422
# 경기도 평택시 비전1동(4122062000)            0.000425
# 경기도 오산시 (4137000000)                0.000430
# 대전광역시 유성구 신성동(3020055000)           0.000432
# 서울특별시 노원구 상계8동(1135070000)          0.000432
# 대전광역시 유성구 (3020000000)              0.000439
# 경기도 용인시 수지구 풍덕천1동(4146551000)       0.000441
# ...

# %%
i = z.sort_values().index[:5]
i
# Out:
# Index(['경기도 안양시 동안구 부림동(4117356600)', '경기도 군포시 오금동(4141058000)',
#        '경기도 광명시 하안2동(4121063200)', '인천광역시 서구 검암경서동(2826051500)',
#        '충청남도 천안시 서북구 (4413300000)'],
#       dtype='object', name='행정구역')

# %%
df.loc[i].T.plot()

# %% [markdown]
# KBR Report에서 오른쪽 위 표 데이터(현재 승패) 가져와서 출력하기
# http://www.kbreport.com

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'http://www.kbreport.com/main'
url = 'file:///C:/Users/wtime/Downloads/팀%20타격메인기록%20_%20KBReport.html'

tables = pd.read_html(url, index_col=1)

# %%
baseball = tables[0]
baseball.shape
# Out:
# (11, 20)

# %%
data= baseball.iloc[:-1]

# %%
data
# Out:
#          #  경기   승  무   패     승률   기대승률   R/G   득점  홈런  도루   볼넷%   삼진%  BABIP  \
# 팀명
# SK     1.0  77  51  1  25  0.671  0.606  4.70  362  69  56   8.5  17.7  0.303
# 두산     2.0  78  48  0  30  0.615  0.625  5.03  392  47  52  11.3  15.5  0.313
# LG     3.0  76  43  1  32  0.573  0.522  4.25  323  48  55   8.1  17.0  0.303
# Hero   4.0  79  45  0  34  0.570  0.597  5.34  422  59  57   9.3  17.2  0.326
# NC     5.0  76  37  0  39  0.487  0.486  4.64  353  71  37   7.7  16.9  0.318
# 삼성     6.0  76  33  0  43  0.434  0.480  4.66  353  68  58   8.6  18.0  0.308
# KIA    7.0  76  32  1  43  0.427  0.433  4.47  340  41  50   9.5  17.0  0.317
# KT     8.0  78  33  0  45  0.423  0.411  4.27  333  52  52   8.7  18.3  0.319
# 한화     9.0  76  31  0  45  0.408  0.443  4.45  338  51  67   9.1  21.2  0.305
# 롯데    10.0  76  29  1  46  0.387  0.420  4.78  363  47  39   9.0  19.1  0.314
#
#          타율    출루율    장타율    OPS   wOBA    WAR
# 팀명
# SK    0.263  0.337  0.387  0.724  0.329   8.69
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, SK to 롯데
# Data columns (total 20 columns):
# #        10 non-null float64
# 경기       10 non-null int64
# 승        10 non-null int64
# 무        10 non-null int64
# 패        10 non-null int64
# 승률       10 non-null object
# 기대승률     10 non-null object
# R/G      10 non-null float64
# 득점       10 non-null int64
# 홈런       10 non-null int64
# 도루       10 non-null int64
# 볼넷%      10 non-null float64
# 삼진%      10 non-null float64
# BABIP    10 non-null float64
# 타율       10 non-null float64
# 출루율      10 non-null float64
# 장타율      10 non-null float64
# OPS      10 non-null float64
# wOBA     10 non-null float64
# WAR      10 non-null float64
# dtypes: float64(11), int64(7), object(2)
# memory usage: 1.6+ KB

# %%
data['승률'], data.기대승률
# Out:
# (팀명
#  SK      0.671
#  두산      0.615
#  LG      0.573
#  Hero    0.570
#  NC      0.487
#  삼성      0.434
#  KIA     0.427
#  KT      0.423
#  한화      0.408
#  롯데      0.387
#  Name: 승률, dtype: object, 팀명
#  SK      0.606
#  두산      0.625
#  LG      0.522
#  Hero    0.597
#  NC      0.486
#  삼성      0.480
#  KIA     0.433
#  KT      0.411
#  한화      0.443
#  롯데      0.420
#  Name: 기대승률, dtype: object)

# %%
#
#data['기대승률']
data.loc[:,'승률'] = data['승률'].astype('float') #타입 변경 후 write
data.loc[:,'기대승률'] = data['기대승률'].astype('float') #타입 변경 후 write

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, SK to 롯데
# Data columns (total 20 columns):
# #        10 non-null float64
# 경기       10 non-null int64
# 승        10 non-null int64
# 무        10 non-null int64
# 패        10 non-null int64
# 승률       10 non-null float64
# 기대승률     10 non-null float64
# R/G      10 non-null float64
# 득점       10 non-null int64
# 홈런       10 non-null int64
# 도루       10 non-null int64
# 볼넷%      10 non-null float64
# 삼진%      10 non-null float64
# BABIP    10 non-null float64
# 타율       10 non-null float64
# 출루율      10 non-null float64
# 장타율      10 non-null float64
# OPS      10 non-null float64
# wOBA     10 non-null float64
# WAR      10 non-null float64
# dtypes: float64(13), int64(7)
# memory usage: 1.6+ KB

# %%
data / 10
# Out:
#         #   경기    승    무    패      승률    기대승률    R/G    득점   홈런   도루   볼넷%  \
# 팀명
# SK    0.1  7.7  5.1  0.1  2.5  0.0671  0.0606  0.470  36.2  6.9  5.6  0.85
# 두산    0.2  7.8  4.8  0.0  3.0  0.0615  0.0625  0.503  39.2  4.7  5.2  1.13
# LG    0.3  7.6  4.3  0.1  3.2  0.0573  0.0522  0.425  32.3  4.8  5.5  0.81
# Hero  0.4  7.9  4.5  0.0  3.4  0.0570  0.0597  0.534  42.2  5.9  5.7  0.93
# NC    0.5  7.6  3.7  0.0  3.9  0.0487  0.0486  0.464  35.3  7.1  3.7  0.77
# 삼성    0.6  7.6  3.3  0.0  4.3  0.0434  0.0480  0.466  35.3  6.8  5.8  0.86
# KIA   0.7  7.6  3.2  0.1  4.3  0.0427  0.0433  0.447  34.0  4.1  5.0  0.95
# KT    0.8  7.8  3.3  0.0  4.5  0.0423  0.0411  0.427  33.3  5.2  5.2  0.87
# 한화    0.9  7.6  3.1  0.0  4.5  0.0408  0.0443  0.445  33.8  5.1  6.7  0.91
# 롯데    1.0  7.6  2.9  0.1  4.6  0.0387  0.0420  0.478  36.3  4.7  3.9  0.90
#
#        삼진%   BABIP      타율     출루율     장타율     OPS    wOBA    WAR
# 팀명
# SK    1.77  0.0303  0.0263  0.0337  0.0387  0.0724  0.0329  0.869
# ...

# %%
plt.barh(data.index, data['승률'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.barh(data.index, data['홈런'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.plot(data.index, data['득점'])

# %%
plt.scatter(data.index, data['득점'])

# %%
plt.bar(data.index, data['득점'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.plot(data.index, data['득점'])
plt.scatter(data.index, data['득점'])
plt.bar(data.index, data['득점'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.plot(data.index, data['승률'])
col = ['승률','기대승률','타율','출루율','장타율']
for c in col:
    plt.plot(data.index, data[c], label=c)
plt.plot(data.index, data['볼넷%']/data['볼넷%'].max(), label='볼넷')
plt.plot(data.index, data['삼진%']/data['삼진%'].max(), label='삼진')
plt.legend()

# %%
plt.title('홈런 비율')
p = plt.pie(data.홈런, labels=data.index, autopct='%.1f')

# %%
p = plt.title('득점 분포')
p = plt.hist(data.득점/data.경기, bins=10)

# %%
name = input('홈팀을 말해주세요')
name
# Out:
# 홈팀을 말해주세요두산
# '두산'

# %%
home = data.loc[name]

# %%
home
# Out:
# #          2.000
# 경기        78.000
# 승         48.000
# 무          0.000
# 패         30.000
# 승률         0.615
# 기대승률       0.625
# R/G        5.030
# 득점       392.000
# 홈런        47.000
# 도루        52.000
# 볼넷%       11.300
# 삼진%       15.500
# BABIP      0.313
# 타율         0.273
# 출루율        0.361
# 장타율        0.390
# OPS        0.751
# wOBA       0.346
# WAR       14.220
# Name: 두산, dtype: float64

# %%
#정규화
data.max()  # 컬럼별 최대값
# Out:
# #         10.000
# 경기        79.000
# 승         51.000
# 무          1.000
# 패         46.000
# 승률         0.671
# 기대승률       0.625
# R/G        5.340
# 득점       422.000
# 홈런        71.000
# 도루        67.000
# 볼넷%       11.300
# 삼진%       21.200
# BABIP      0.326
# 타율         0.280
# 출루율        0.361
# 장타율        0.419
# OPS        0.762
# wOBA       0.346
# WAR       14.430
# dtype: float64

# %%
data_normal = data/data.max()
data_normal
# Out:
#         #        경기         승    무         패        승률    기대승률       R/G  \
# 팀명
# SK    0.1  0.974684  1.000000  1.0  0.543478  1.000000  0.9696  0.880150
# 두산    0.2  0.987342  0.941176  0.0  0.652174  0.916542  1.0000  0.941948
# LG    0.3  0.962025  0.843137  1.0  0.695652  0.853949  0.8352  0.795880
# Hero  0.4  1.000000  0.882353  0.0  0.739130  0.849478  0.9552  1.000000
# NC    0.5  0.962025  0.725490  0.0  0.847826  0.725782  0.7776  0.868914
# 삼성    0.6  0.962025  0.647059  0.0  0.934783  0.646796  0.7680  0.872659
# KIA   0.7  0.962025  0.627451  1.0  0.934783  0.636364  0.6928  0.837079
# KT    0.8  0.987342  0.647059  0.0  0.978261  0.630402  0.6576  0.799625
# 한화    0.9  0.962025  0.607843  0.0  0.978261  0.608048  0.7088  0.833333
# 롯데    1.0  0.962025  0.568627  1.0  1.000000  0.576751  0.6720  0.895131
#
#             득점        홈런        도루       볼넷%       삼진%     BABIP        타율  \
# 팀명
# SK    0.857820  0.971831  0.835821  0.752212  0.834906  0.929448  0.939286
# ...

# %%
home = data_normal.loc[name]
#홈팀과 다른팀과의 차이, 차이가 작은 팀을 찾습니다.
np.square(data_normal - home)
# Out:
#          #        경기         승    무         패        승률      기대승률       R/G  \
# 팀명
# SK    0.01  0.000160  0.003460  1.0  0.011815  0.006965  0.000924  0.003819
# 두산    0.00  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# LG    0.01  0.000641  0.009612  1.0  0.001890  0.003918  0.027159  0.021336
# Hero  0.04  0.000160  0.003460  0.0  0.007561  0.004498  0.002007  0.003370
# NC    0.09  0.000641  0.046521  0.0  0.038280  0.036389  0.049462  0.005334
# 삼성    0.16  0.000641  0.086505  0.0  0.079868  0.072763  0.053824  0.004801
# KIA   0.25  0.000641  0.098424  1.0  0.079868  0.078500  0.094372  0.010997
# KT    0.36  0.000000  0.086505  0.0  0.106333  0.081876  0.117238  0.020256
# 한화    0.49  0.000641  0.111111  0.0  0.106333  0.095169  0.084797  0.011797
# 롯데    0.64  0.000641  0.138793  1.0  0.120983  0.115458  0.107584  0.002192
#
#             득점        홈런        도루       볼넷%       삼진%     BABIP        타율  \
# 팀명
# ...

# %%
차이 = np.sum(np.square(data_normal - home), axis =1)

# %%
차이
# Out:
# 팀명
# SK      1.371164
# 두산      0.000000
# LG      1.602978
# Hero    0.143184
# NC      0.583979
# 삼성      0.711208
# KIA     1.771967
# KT      1.101993
# 한화      1.559221
# 롯데      2.524706
# dtype: float64

# %%
i = 차이.sort_values().index[:5]
data.loc[i].T.plot(figsize=(5,3))

# %%
data.loc[i,['홈런','득점','승']].T.plot(figsize=(5,3))

# %%
home.plot()

# %%
np.mean(data.득점/data.경기)
# Out:
# 4.657478475333239
